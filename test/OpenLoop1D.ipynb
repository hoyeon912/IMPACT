# %%
import sys
sys.path.append("../")

# %%
from impact.communication.mmap_comm import MmapCommunication
from impact.envs.virmen_env import OpenLoop1D

# %%
comm = MmapCommunication(
    flag_path='../test/flag.mmap',
    image_path='../test/image.mmap',
    position_path='../test/position.mmap',
    event_path='../test/event.mmap',
    action_path='../test/action.mmap',
    image_shape=(192, 108, 3),
    action_dim=1,
    event_dim=1,
    position_dim=4
)
env = OpenLoop1D(comm=comm, setting_path="../test/setting.json")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 comm = MmapCommunication(
#       2     flag_path='../test/flag.mmap',
#       3     image_path='../test/image.mmap',
#       4     position_path='../test/position.mmap',
#       5     event_path='../test/event.mmap',
#       6     action_path='../test/action.mmap',
#       7     image_shape=(192, 108, 3),
#       8     action_dim=1,
#       9     event_dim=1,
#      10     position_dim=1
#      11 )
#      12 env = OpenLoop1D(comm=comm, setting_path="../test/setting.json")
#
# File ~/Codes/IMPACT/test/../impact/communication/mmap_comm.py:48, in MmapCommunication.__init__(self, flag_path, image_path, position_path, event_path, action_path, image_shape, position_dim, event_dim, action_dim, mode)
#      45 self._action_path = Path(action_path)
#      46 self._mode = mode
# ---> 48 self.open()
#
# ...
